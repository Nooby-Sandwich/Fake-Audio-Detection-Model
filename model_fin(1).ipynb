# %% [markdown]
# 특징 추출 및 모델 학습

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     131   )
#     132   if ephemeral:
# --> 133     _message.blocking_request(
#     134         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
#     135     )
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
# 특징추출_mffcc_chroma_tonnetz

import librosa
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv1D, MaxPooling1D
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
import glob
import os
from imblearn.over_sampling import SMOTE

def get_files_from_dir(path, file_format):
    # 주어진 경로와 그 하위 경로에서 특정 형식의 파일들을 찾습니다.
    return glob.glob(os.path.join(path, f'**/*.{file_format}'), recursive=True)

# 데이터 증강 함수
def augment_data(y, sr):
    y_changed = librosa.effects.time_stretch(y, rate=0.81)
    y_changed = librosa.effects.pitch_shift(y_changed, sr=sr, n_steps=4)

    return y_changed

def extract_features(audio_files):
    features = []

    for audio_file in audio_files:
        try:
            y, sr = librosa.load(audio_file)

            # 원본 데이터에 대한 특성 추출(n_fft, hop_length 감소)
            mfccs = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_fft=1024, hop_length=256), axis=1)
            chroma_cqt = np.mean(librosa.feature.chroma_cqt(y=y, sr=sr, hop_length=256), axis=1)
            tonnetz = np.mean(librosa.feature.tonnetz(y=y, sr=sr), axis=1)

            original_features = np.hstack([mfccs, chroma_cqt, tonnetz])

            features.append(original_features)

            # 증강된 데이터에 대한 특성 추출(n_fft, hop_length 감소)
            y_augmented = augment_data(y, sr)

            mfccs_augmented = np.mean(librosa.feature.mfcc(y=y_augmented, sr=sr, n_fft=1024, hop_length=256), axis=1)
            chroma_cqt_augmented = np.mean(librosa.feature.chroma_cqt(y=y_augmented, sr=sr, hop_length=256), axis=1)
            tonnetz_augmented = np.mean(librosa.feature.tonnetz(y=y_augmented, sr=sr), axis=1)

            augmented_features = np.hstack([mfccs_augmented, chroma_cqt_augmented, tonnetz_augmented])

            features.append(augmented_features)

        except Exception as e:
            print(f"Error processing {audio_file}: {str(e)}")

    return np.array(features)

ai_audio_files=get_files_from_dir('/content/drive/MyDrive/음성데이터셋/03fin48_ai_koen_padding_cut_no_noise', 'wav')
human_audio_files=get_files_from_dir('/content/drive/MyDrive/음성데이터셋/03fin48_human_koen_padding_cut_no_noise', 'wav')

# AI 음성 특징 추출 및 레이블 생성
ai_features_train_test_fullset=extract_features(ai_audio_files)
ai_labels_train_test_fullset=np.zeros(len(ai_features_train_test_fullset))

# 사람 음성 특징 추출 및 레이블 생성
human_features_train_test_fullset=extract_features(human_audio_files)
human_labels_train_test_fullset=np.ones(len(human_features_train_test_fullset))

X_train,X_val,y_train,y_val=train_test_split(np.concatenate([ai_features_train_test_fullset,human_features_train_test_fullset]),
                                             np.concatenate([ai_labels_train_test_fullset,human_labels_train_test_fullset]),test_size=0.2)

# %%
# CNN 모델

# 원-핫 인코딩을 위해 y 값을 변환
from keras.utils import to_categorical
y_train = to_categorical(y_train, num_classes=2)
y_val = to_categorical(y_val, num_classes=2)

# 데이터 차원 재조정 (Conv1D 레이어는 3차원 입력을 기대합니다)
X_train = np.expand_dims(X_train, axis=2)
X_val = np.expand_dims(X_val, axis=2)

from keras.layers import BatchNormalization, Conv1D

model = Sequential()
model.add(Conv1D(64, kernel_size=3, activation='relu', padding='same', input_shape=(X_train.shape[1], 1)))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.25))

model.add(Conv1D(128, kernel_size=3, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(2, activation='softmax'))

optimizer = Adam(learning_rate=0.001)

model.compile(loss='categorical_crossentropy', optimizer=optimizer ,metrics=['accuracy'])

print(model.summary())

early_stopping = EarlyStopping(monitor='val_loss', patience=10)

history=model.fit(X_train,y_train,batch_size=64, epochs=100, validation_data=(X_val,y_val))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 38, 64)            256
#
#  batch_normalization (Batch  (None, 38, 64)            256
#  Normalization)
#
#  max_pooling1d (MaxPooling1  (None, 19, 64)            0
#  D)
#
#  dropout (Dropout)           (None, 19, 64)            0
#
#  conv1d_1 (Conv1D)           (None, 19, 128)           24704
#
#  batch_normalization_1 (Bat  (None, 19, 128)           512
#  chNormalization)
#
#  max_pooling1d_1 (MaxPoolin  (None, 9, 128)            0
#  g1D)
#
#  dropout_1 (Dropout)         (None, 9, 128)            0
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 256)               295168
#
#  batch_normalization_2 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 322434 (1.23 MB)
# Trainable params: 321538 (1.23 MB)
# Non-trainable params: 896 (3.50 KB)
# _________________________________________________________________
# None
# Epoch 1/100
# 100/100 [==============================] - 13s 7ms/step - loss: 0.8488 - accuracy: 0.6334 - val_loss: 1.3764 - val_accuracy: 0.5138
# Epoch 2/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.6219 - accuracy: 0.6866 - val_loss: 0.6757 - val_accuracy: 0.6319
# Epoch 3/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.5746 - accuracy: 0.6998 - val_loss: 0.4834 - val_accuracy: 0.7738
# Epoch 4/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.5312 - accuracy: 0.7281 - val_loss: 0.4753 - val_accuracy: 0.7656
# Epoch 5/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.5115 - accuracy: 0.7367 - val_loss: 0.4999 - val_accuracy: 0.7419
# Epoch 6/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4998 - accuracy: 0.7478 - val_loss: 0.4932 - val_accuracy: 0.7487
# Epoch 7/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4868 - accuracy: 0.7548 - val_loss: 0.4792 - val_accuracy: 0.7594
# Epoch 8/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4804 - accuracy: 0.7558 - val_loss: 0.4278 - val_accuracy: 0.8031
# Epoch 9/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4792 - accuracy: 0.7617 - val_loss: 0.4335 - val_accuracy: 0.7950
# Epoch 10/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4673 - accuracy: 0.7628 - val_loss: 0.4264 - val_accuracy: 0.8012
# Epoch 11/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.4594 - accuracy: 0.7716 - val_loss: 0.4849 - val_accuracy: 0.7613
# Epoch 12/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4515 - accuracy: 0.7752 - val_loss: 0.4363 - val_accuracy: 0.7925
# Epoch 13/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.4457 - accuracy: 0.7833 - val_loss: 0.4587 - val_accuracy: 0.7706
# Epoch 14/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4379 - accuracy: 0.7881 - val_loss: 0.3891 - val_accuracy: 0.8250
# Epoch 15/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4362 - accuracy: 0.7848 - val_loss: 0.3798 - val_accuracy: 0.8200
# Epoch 16/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4401 - accuracy: 0.7852 - val_loss: 0.4812 - val_accuracy: 0.7356
# Epoch 17/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4347 - accuracy: 0.7859 - val_loss: 0.3942 - val_accuracy: 0.8219
# Epoch 18/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4269 - accuracy: 0.7903 - val_loss: 0.4306 - val_accuracy: 0.7844
# Epoch 19/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4208 - accuracy: 0.8011 - val_loss: 0.3988 - val_accuracy: 0.8012
# Epoch 20/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4187 - accuracy: 0.8000 - val_loss: 0.3770 - val_accuracy: 0.8269
# Epoch 21/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4158 - accuracy: 0.8014 - val_loss: 0.3576 - val_accuracy: 0.8469
# Epoch 22/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4133 - accuracy: 0.8031 - val_loss: 0.3581 - val_accuracy: 0.8431
# Epoch 23/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4001 - accuracy: 0.8112 - val_loss: 0.3660 - val_accuracy: 0.8269
# Epoch 24/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4068 - accuracy: 0.8116 - val_loss: 0.3552 - val_accuracy: 0.8269
# Epoch 25/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3992 - accuracy: 0.8131 - val_loss: 0.3549 - val_accuracy: 0.8319
# Epoch 26/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3974 - accuracy: 0.8091 - val_loss: 0.3273 - val_accuracy: 0.8531
# Epoch 27/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3961 - accuracy: 0.8120 - val_loss: 0.3480 - val_accuracy: 0.8369
# Epoch 28/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3900 - accuracy: 0.8172 - val_loss: 0.3480 - val_accuracy: 0.8419
# Epoch 29/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3899 - accuracy: 0.8216 - val_loss: 0.3887 - val_accuracy: 0.8100
# Epoch 30/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3861 - accuracy: 0.8230 - val_loss: 0.3130 - val_accuracy: 0.8594
# Epoch 31/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3828 - accuracy: 0.8178 - val_loss: 0.3664 - val_accuracy: 0.8206
# Epoch 32/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3714 - accuracy: 0.8294 - val_loss: 0.3160 - val_accuracy: 0.8637
# Epoch 33/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3836 - accuracy: 0.8275 - val_loss: 0.3310 - val_accuracy: 0.8394
# Epoch 34/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3694 - accuracy: 0.8317 - val_loss: 0.3011 - val_accuracy: 0.8656
# Epoch 35/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3766 - accuracy: 0.8309 - val_loss: 0.3059 - val_accuracy: 0.8744
# Epoch 36/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3627 - accuracy: 0.8309 - val_loss: 0.3029 - val_accuracy: 0.8700
# Epoch 37/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3616 - accuracy: 0.8330 - val_loss: 0.2984 - val_accuracy: 0.8694
# Epoch 38/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3591 - accuracy: 0.8386 - val_loss: 0.2845 - val_accuracy: 0.8794
# Epoch 39/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3650 - accuracy: 0.8305 - val_loss: 0.3287 - val_accuracy: 0.8469
# Epoch 40/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3577 - accuracy: 0.8361 - val_loss: 0.2939 - val_accuracy: 0.8687
# Epoch 41/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3485 - accuracy: 0.8434 - val_loss: 0.3168 - val_accuracy: 0.8575
# Epoch 42/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3464 - accuracy: 0.8423 - val_loss: 0.2937 - val_accuracy: 0.8619
# Epoch 43/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3518 - accuracy: 0.8377 - val_loss: 0.2821 - val_accuracy: 0.8813
# Epoch 44/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3442 - accuracy: 0.8461 - val_loss: 0.2763 - val_accuracy: 0.8781
# Epoch 45/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3410 - accuracy: 0.8472 - val_loss: 0.2822 - val_accuracy: 0.8781
# Epoch 46/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3441 - accuracy: 0.8498 - val_loss: 0.2760 - val_accuracy: 0.8875
# Epoch 47/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3349 - accuracy: 0.8484 - val_loss: 0.2724 - val_accuracy: 0.8769
# Epoch 48/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3362 - accuracy: 0.8523 - val_loss: 0.2973 - val_accuracy: 0.8662
# Epoch 49/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3266 - accuracy: 0.8533 - val_loss: 0.2867 - val_accuracy: 0.8744
# Epoch 50/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3283 - accuracy: 0.8556 - val_loss: 0.2718 - val_accuracy: 0.8850
# Epoch 51/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3382 - accuracy: 0.8495 - val_loss: 0.2793 - val_accuracy: 0.8781
# Epoch 52/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3157 - accuracy: 0.8553 - val_loss: 0.2710 - val_accuracy: 0.8863
# Epoch 53/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3154 - accuracy: 0.8609 - val_loss: 0.2632 - val_accuracy: 0.8938
# Epoch 54/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3276 - accuracy: 0.8608 - val_loss: 0.3097 - val_accuracy: 0.8556
# Epoch 55/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3231 - accuracy: 0.8491 - val_loss: 0.2796 - val_accuracy: 0.8775
# Epoch 56/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3260 - accuracy: 0.8559 - val_loss: 0.2620 - val_accuracy: 0.8863
# Epoch 57/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3153 - accuracy: 0.8608 - val_loss: 0.2526 - val_accuracy: 0.8919
# Epoch 58/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3067 - accuracy: 0.8625 - val_loss: 0.3061 - val_accuracy: 0.8594
# Epoch 59/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3055 - accuracy: 0.8606 - val_loss: 0.2572 - val_accuracy: 0.8931
# Epoch 60/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3173 - accuracy: 0.8530 - val_loss: 0.2691 - val_accuracy: 0.8806
# Epoch 61/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3116 - accuracy: 0.8653 - val_loss: 0.2485 - val_accuracy: 0.8963
# Epoch 62/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2915 - accuracy: 0.8687 - val_loss: 0.2425 - val_accuracy: 0.9000
# Epoch 63/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3055 - accuracy: 0.8633 - val_loss: 0.2551 - val_accuracy: 0.8838
# Epoch 64/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2981 - accuracy: 0.8644 - val_loss: 0.2495 - val_accuracy: 0.8981
# Epoch 65/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2978 - accuracy: 0.8673 - val_loss: 0.2642 - val_accuracy: 0.8875
# Epoch 66/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2849 - accuracy: 0.8716 - val_loss: 0.2396 - val_accuracy: 0.8963
# Epoch 67/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2904 - accuracy: 0.8711 - val_loss: 0.2475 - val_accuracy: 0.8975
# Epoch 68/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2876 - accuracy: 0.8720 - val_loss: 0.2432 - val_accuracy: 0.8956
# Epoch 69/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2851 - accuracy: 0.8744 - val_loss: 0.2454 - val_accuracy: 0.8950
# Epoch 70/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2816 - accuracy: 0.8745 - val_loss: 0.2469 - val_accuracy: 0.8931
# Epoch 71/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2766 - accuracy: 0.8814 - val_loss: 0.2406 - val_accuracy: 0.8925
# Epoch 72/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2838 - accuracy: 0.8816 - val_loss: 0.2396 - val_accuracy: 0.8975
# Epoch 73/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2722 - accuracy: 0.8788 - val_loss: 0.2497 - val_accuracy: 0.8969
# Epoch 74/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2828 - accuracy: 0.8773 - val_loss: 0.2442 - val_accuracy: 0.8931
# Epoch 75/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2825 - accuracy: 0.8747 - val_loss: 0.2430 - val_accuracy: 0.8906
# Epoch 76/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2903 - accuracy: 0.8702 - val_loss: 0.2450 - val_accuracy: 0.8950
# Epoch 77/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2799 - accuracy: 0.8808 - val_loss: 0.2387 - val_accuracy: 0.8956
# Epoch 78/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2688 - accuracy: 0.8813 - val_loss: 0.2722 - val_accuracy: 0.8712
# Epoch 79/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2672 - accuracy: 0.8833 - val_loss: 0.2449 - val_accuracy: 0.8919
# Epoch 80/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2637 - accuracy: 0.8819 - val_loss: 0.2318 - val_accuracy: 0.8981
# Epoch 81/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2659 - accuracy: 0.8858 - val_loss: 0.2595 - val_accuracy: 0.8919
# Epoch 82/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2672 - accuracy: 0.8834 - val_loss: 0.2359 - val_accuracy: 0.8981
# Epoch 83/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2727 - accuracy: 0.8783 - val_loss: 0.2463 - val_accuracy: 0.8900
# Epoch 84/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2666 - accuracy: 0.8858 - val_loss: 0.2364 - val_accuracy: 0.9019
# Epoch 85/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2699 - accuracy: 0.8884 - val_loss: 0.2309 - val_accuracy: 0.9031
# Epoch 86/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2624 - accuracy: 0.8895 - val_loss: 0.2269 - val_accuracy: 0.9019
# Epoch 87/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2597 - accuracy: 0.8848 - val_loss: 0.2314 - val_accuracy: 0.9050
# Epoch 88/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2563 - accuracy: 0.8928 - val_loss: 0.2236 - val_accuracy: 0.9025
# Epoch 89/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2710 - accuracy: 0.8811 - val_loss: 0.2296 - val_accuracy: 0.8981
# Epoch 90/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2472 - accuracy: 0.8916 - val_loss: 0.2436 - val_accuracy: 0.8913
# Epoch 91/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2583 - accuracy: 0.8883 - val_loss: 0.2210 - val_accuracy: 0.9081
# Epoch 92/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2504 - accuracy: 0.8934 - val_loss: 0.2509 - val_accuracy: 0.8919
# Epoch 93/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2569 - accuracy: 0.8875 - val_loss: 0.2421 - val_accuracy: 0.8950
# Epoch 94/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2557 - accuracy: 0.8903 - val_loss: 0.2285 - val_accuracy: 0.9044
# Epoch 95/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2665 - accuracy: 0.8841 - val_loss: 0.2311 - val_accuracy: 0.8994
# Epoch 96/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2516 - accuracy: 0.8941 - val_loss: 0.2186 - val_accuracy: 0.9106
# Epoch 97/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2477 - accuracy: 0.8948 - val_loss: 0.2150 - val_accuracy: 0.9062
# Epoch 98/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2483 - accuracy: 0.8923 - val_loss: 0.2119 - val_accuracy: 0.9069
# Epoch 99/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2470 - accuracy: 0.8961 - val_loss: 0.2357 - val_accuracy: 0.8956
# Epoch 100/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2446 - accuracy: 0.8905 - val_loss: 0.2235 - val_accuracy: 0.9119

# %%
import pickle

#모델 저장
model.save('/content/drive/MyDrive/코드/model_fin.h5')  # h5 확장자를 사용합니다.

# history 저장
with open('/content/drive/MyDrive/코드/history.pkl', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
